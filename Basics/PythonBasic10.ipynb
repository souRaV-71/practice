# %% [markdown]
# 1. How do you distinguish between shutil.copy() and shutil.copytree()?

# %% [markdown]
# shutil.copy() will copy a single file.
# <br>
# shutil.copytree() will copy an entire folder and every folder and file contained in it.

# %% [markdown]
# 2. What function is used to rename files??

# %% [markdown]
# os.rename() function is used to rename files or directories using a python program, this function takes two arguments src and dest, src represents the name file/directory which we want to rename, whereas dest represents the new name of the file/directory.

# %% [markdown]
# 3. What is the difference between the delete functions in the send2trash and shutil modules?

# %% [markdown]
# Shutil module provides a funciton called as shutil.rmtree() which deletes a directory and all its contents.
# <br>
# The other functions with similar functionality are os.remove() -> removes a file, os.rmdir() removes a empty directory.
# <br>
# The problem with these functions is once a file is deleted it will be lost permanently, if happened accidentally then there is no way we can recover the deleted file.
#
# Whereas send2trash module provides a function called send2trash.send2trash() to delete a file/directory.
# <br>
# These methods moves the files/directories to trash folder instead of permanently deleting them,hence if a file/folder is deleted accidentally it can be still recovered from trash folder, if is deleted using the send2trash.send2trash() function.
# <br>
# send2trash is not included with python standard libary like os & shutil modules. it needs to be installed explicitly using the command "!pip install send2trash"

# %% [markdown]
# 4. ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is
# equivalent to File objects’ open() method?

# %% [markdown]
# The zipfile. ZipFile() function is equivalent to the open() function; the first argument is the filename, and the second argument is the mode to open the ZIP file in (read, write, or append).
# <br>
# zipfile.ZipFile('filename', mode = 'r')

# %% [markdown]
# 5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf
# or .jpg). Copy these files from whatever location they are in to a new folder.

# %%
import os
import shutil

def srch_and_cpy(src,dest,extensions):
    src = os.path.abspath(src)
    dest = os.path.abspath(dest)
    for foldername, subfolder, filenames in os.walk(src):
        print(f'Folder Name ➞ {foldername}',end='\n\n')
        print(f'Sub Folders ➞ {subfolder}',end='\n\n')
        print(f'Files ➞ {filenames}',end='\n\n')
        for filename in filenames:
            fileName,extension = os.path.splitext(filename)
            if extension in extensions:
                targetFile = foldername+os.path.sep+fileName+extension
                shutil.copy(targetFile, dest)
        print(f'Files copied successfully from {src} to {dest}')
    
extensions = ['.pdf','.jpg','.ipynb']
src = '/home/d/'
dest = '/home/d/ccppyy/'
srch_and_cpy(src, dest, extensions)
# Out:
# Folder Name ➞ /home/d
#
# Sub Folders ➞ ['.dotnet', '.local', '.cache', '.ipython', 'ccppyy', '.vscode-server-insiders', 'practice']
#
# Files ➞ ['.bashrc', '.wget-hsts', '.bash_history', '.bash_logout', '.profile']
#
# Files copied successfully from /home/d to /home/d/ccppyy
# Folder Name ➞ /home/d/.dotnet
#
# Sub Folders ➞ ['corefx']
#
# Files ➞ []
#
# Files copied successfully from /home/d to /home/d/ccppyy
# Folder Name ➞ /home/d/.dotnet/corefx
#
# Sub Folders ➞ ['cryptography']
#
# Files ➞ []
#
# Files copied successfully from /home/d to /home/d/ccppyy
# Folder Name ➞ /home/d/.dotnet/corefx/cryptography
#
# Sub Folders ➞ ['crls']
#
# Files ➞ []
#
# Files copied successfully from /home/d to /home/d/ccppyy
# Folder Name ➞ /home/d/.dotnet/corefx/cryptography/crls
#
# Sub Folders ➞ []
#
# Files ➞ ['7abcc12f.dea36fd7.crl', 'd16da424.cbeb964c.crl', '7462804f.d5a68194.crl', '75d1b2ed.de05bb98.crl']
#
# Files copied successfully from /home/d to /home/d/ccppyy
# ...
